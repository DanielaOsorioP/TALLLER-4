# %% [markdown]
# <a href="https://colab.research.google.com/github/DanielaOsorioP/TALLLER-4/blob/main/Taller_4_EJERCICIO_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Problema #3: Juego de Cara o Sello
Crea un programa que permita jugar a "Cara o Sello" con el usuario. El programa seleccionará de
manera aleatoria "cara" o "sello" y luego pedirá al usuario que haga su adivinanza. Si acierta, se le
sumará un punto. Si falla, tendrá tres intentos antes de que el juego termine. Al finalizar el juego, se le
mostrará al usuario la cantidad de puntos obtenidos y se le preguntará si quiere jugar de nuevo. Si el
usuario elige "sí", el juego se reinicia. Si elige "no", el programa finaliza.

ALGORITMO:
Algoritmo para crear un programa que permita jugar a "Cara o Sello" conel usuario.

1.	Inicializar una variable puntos en 0.
2.	Iniciar un bucle que se repetirá hasta que el usuario decida finalizar.
3.	Dentro del bucle:
o	Seleccionar de manera aleatoria "cara" o "sello".
o	Solicitar al usuario que haga su adivinanza.
o	Comparar la adivinanza del usuario con la opción aleatoria.
o	Si acierta, sumar un punto.
o	Si falla, permitir que el usuario tenga tres intentos.
o	Después de los tres intentos, terminar el juego.
4.	Mostrar el puntaje total al usuario.
5.	Preguntar al usuario si desea jugar de nuevo.
o	Si la respuesta es "sí", reiniciar el juego (regresar al paso 1).
o	Si la respuesta es "no", finalizar el programa.

PSEUDOCODIGO:
INICIO
    puntos ← 0
    repetir ← "sí"

 MIENTRAS repetir = "sí" HACER
    intentos ← 3
    resultado aleatorio ← GENERAR ALEATORIO ("cara", "sello")

MIENTRAS intentos > 0 HACER
      escribir "Adivina: ¿cara o sello?"
      adivinanza ← LEER USUARIO

SI adivinanza = resultado_aleatorio ENTONCES
      puntos ← puntos + 1
      escribir "¡Acertaste! Puntos actuales: ", puntos romper
SINO
    intentos ← intentos - 1
    escribir "Fallaste. Intentos restantes: ", intentos
FIN SI
FIN MIENTRAS

escribir "Tu puntaje final es: ", puntos
escribir "¿Quieres jugar de nuevo? (sí/no)"
repetir ← LEER USUARIO
FIN MIENTRAS

FIN



PYTHON:

import random

def jugar_cara_o_sello():
    puntos = 0
    repetir = "sí"

while repetir.lower() == "sí":
     intentos = 3
    resultado_aleatorio = random.choice(["cara", "sello"])

while intentos > 0:
  adivinanza = input("Adivina: ¿cara o sello? ").lower()

    if adivinanza == resultado_aleatorio:
      puntos += 1
      print(f"¡Acertaste! Puntos actuales: {puntos}")
      break
            else:
                intentos -= 1
                print(f"Fallaste. Intentos restantes: {intentos}")

        print(f"Tu puntaje final es: {puntos}")
        repetir = input("¿Quieres jugar de nuevo? (sí/no): ").lower()

    print("Juego finalizado.")

# Llamar a la función para iniciar el juego
jugar_cara_o_sello()

# %%
Problema #1: Generador de Discurso Político
Imagina que formas parte de un equipo de campaña que necesita crear discursos políticos
rápidamente. Para ello, contarás con una tabla de palabras y frases predefinidas para distintas
secciones de un discurso: título, público objetivo, condición social, compromiso político, lucha social,
promesa, beneficio populista y cantidad de votos (ver Fig. 1). El programa deberá construir un
mensaje político seleccionando aleatoriamente una palabra o frase de cada categoría. El mensaje final
debe mostrarse al terminar la ejecución del programa. Se recomienda el uso de listas, ciclos y la
función de selección aleatoria para generar el discurso. Ejemplo: “Apreciados amigos con su ayuda
venceré la pobreza y promoveré la igualdad de la comunidad.”

ALGORITMO:
algoritmo para crear un programa que genere un discurso politico.

1. INICIO
2. Declarar las listas de palabras
titulo = ["Queridos", "Apreciados", "Distinguidos", "Honorables", "Estimados", "Respetados"]
publico_objetivo = ["compatriotas", "amigos", "compartidarios", "coterráneos", "conciudadanos", "electos"]
condicion = ["en mi gobierno", "con su apoyo", "siendo elegido", "con su ayuda", "si me eligen", "en mi mandato"]
compromiso = ["voy a derrotar", "venceré", "eliminaré", "acabaré", "lucharé", "combatiré"]
ilusion_de_lucha = ["la violencia y", "la delincuencia y", "la corrupción y", "la inflación y", "la pobreza y", "el desplazamiento y"]
promesa = ["trabajaré por", "garantizaré", "protegeré", "velaré por", "promoveré", "defenderé"]
beneficio_populista = ["la educación", "el empleo", "la seguridad", "la paz", "la igualdad", "la salud"]
dependiendo_de_cantidad_de_votos = ["del país", "de la comunidad", "de la ciudad", "de la población", "para toda la gente", "de cada colombiano"]
3. Agrupar las listas en una sola lista llamada elementos
elementos = [titulo, publico_objetivo, condicion, compromiso, ilusion_de_lucha, promesa, beneficio_populista, dependiendo_de_cantidad_de_votos]
4. Seleccionar aleatoriamente una palabra de cada lista y construir el discurso
5. Generación del discurso aleatorio
6. Mostrar discurso
7. FIN

PSEUDOCODIGO:

program discurso politico
start

declaracion de variables//

declare foat titulo  ["Queridos", "Apreciados", "Distinguidos", "Honorables", "Estimados", "Respetados"]
declare foat publico_objetivo ["compatriotas", "amigos", "compartidarios", "coterráneos", "conciudadanos", "electos"]
declare foat condicion ["en mi gobierno", "con su apoyo", "siendo elegido", "con su ayuda", "si me siguen", "durante mi mandato"]
declare foat compromiso ["voy a derrotar", "venceré", "eliminaré", "acabaré", "lucharé", "combatiré"]
declare foat ilusion_de_lucha ["la violencia y", "la delincuencia y", "la corrupción y", "la inflacion y", "la pobreza y", "el desplazamiento y"]
declare foat promesa ["trabajaré por", "garantizaré", "protegeré", "velaré por", "promoveré", "defenderé"]
declare foat beneficio ["la educación", "el empleo", "la seguridad", "la paz", "la igualdad", "la salud"]
declare foat dependiendo_de_cantidad_de_votos ["del país", "de la comunidad", "de la ciudad", "de la población", "para toda la gente", "de cada colombiano"]

declare foat elementos [titulo, publico_objetivo, condicion, compromiso, ilusion_de_lucha, promesa, beneficio, dependiendo_de_cantidad_de_votos]

declare foat discurso
fin


PYTHON:

import random

def generar_discurso():
    # Definir las listas de palabras y frases
    titulo = ["Queridos", "Apreciados", "Distinguidos", "Honorables", "Estimados", "Respetados"]
    publico_objetivo = ["compatriotas", "amigos", "compartidarios", "coterráneos", "conciudadanos", "electos"]
    condicion_social = ["en mi gobierno", "con su apoyo", "siendo elegido", "con su ayuda", "si me eligen", "durante mi mandato"]
    compromiso_politico = ["voy a derrotar", "venceré", "eliminaré", "acabaré", "lucharé", "combatiré"]
    lucha_social = ["la violencia y", "la delincuencia y", "la corrupción y", "la inflación y", "la pobreza y", "el desplazamiento y"]
    promesa = ["trabajaré por", "garantizaré", "protegeré", "velaré por", "promoveré", "defenderé"]
    beneficio_populista = ["la educación", "el empleo", "la seguridad", "la paz", "la igualdad", "la salud"]
    cantidad_de_votos = ["del país", "de la comunidad", "de la ciudad", "de la población", "para toda la gente", "de cada colombiano"]

    # Agrupar las listas en una lista de elementos
    elementos = [titulo, publico_objetivo, condicion_social, compromiso_politico, lucha_social, promesa, beneficio_populista, cantidad_de_votos]

    # Inicializar la variable discurso
    discurso = ""

    # Generación del discurso
    for lista in elementos:
        discurso += random.choice(lista) + " "

    # Mostrar el discurso final
    print(discurso.strip())

# Llamar a la función para generar y mostrar el discurso
generar_discurso()
